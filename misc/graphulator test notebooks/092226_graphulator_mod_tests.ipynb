# %% [markdown]
# # Testing graphulator additions
# ***092226JAA***

# %% [markdown]
# ## Testing code export

# %%
#!/usr/bin/env python
"""
Generated graph code using graph_primitives
"""

import matplotlib.pyplot as plt
import graphulator.graph_primitives as gp
import graphulator.graphulator_config as config

# Create graph circuit (allow duplicate labels)
# Set use_latex=True for LaTeX rendering, False for MathText (default)
graph = gp.GraphCircuit(allow_duplicate_labels=True, use_latex=False)

# Add nodes
# Node 1: B
graph.addnode(label='B', xy=(7.197, 0.000), node_id=0,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 2: C
graph.addnode(label='C', xy=(7.197, -3.000), node_id=1,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 3: A
graph.addnode(label='A', xy=(7.197, 3.000), node_id=2,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)


# Ports, transmission lines and their wiring
graph.addport(label='P1', xy=(-8.803, 0.000), R=0.600, port_id=0, angle=0.0, length=1.100)
graph.addtxline(label='TL1', xy=(-0.803, 0.000), R=0.600, txline_id=0, angle=0.0, length=1.874, height=1.600)
graph.addwire(start=('txline', 0, 'x0'), end=('port', 0))
graph.addwire(start=('txline', 0, 'xL'), end=('node', 2))
graph.addwire(start=('txline', 0, 'xL'), end=('node', 0))
graph.addwire(start=('txline', 0, 'xL'), end=('node', 1))


# Draw the graph
# overfrac adds padding around the graph to ensure all elements are visible
# Increase overfrac if labels or self-loops are cut off
graph.draw(figsize=12, overfrac=0.2)

plt.axis('off')
plt.title('')  # Remove title
plt.show()

# %%
#!/usr/bin/env python
"""
Generated graph code using graph_primitives
"""

import matplotlib.pyplot as plt
import graphulator.graph_primitives as gp
import graphulator.graphulator_config as config

# Create graph circuit (allow duplicate labels)
# Set use_latex=True for LaTeX rendering, False for MathText (default)
graph = gp.GraphCircuit(allow_duplicate_labels=True, use_latex=False)

# Add nodes
# Node 1: A_-2
graph.addnode(label='A_-2', xy=(-6.054, -4.000), node_id=1,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 2: A_{-1}
graph.addnode(label='A_{-1}', xy=(-6.054, -2.000), node_id=2,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 3: A_0
graph.addnode(label='A_0', xy=(-6.054, -0.000), node_id=3,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 4: A_1
graph.addnode(label='A_1', xy=(-6.054, 2.000), node_id=4,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 5: A_2
graph.addnode(label='A_2', xy=(-6.054, 4.000), node_id=5,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 6: A_-2
graph.addnode(label='A_-2', xy=(6.937, 3.500), node_id=6,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 7: A_{-1}
graph.addnode(label='A_{-1}', xy=(5.205, 4.500), node_id=7,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 8: A_0
graph.addnode(label='A_0', xy=(3.473, 5.500), node_id=8,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 9: A_1
graph.addnode(label='A_1', xy=(1.741, 6.500), node_id=9,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 10: A_2
graph.addnode(label='A_2', xy=(0.008, 7.500), node_id=10,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 11: A_-2
graph.addnode(label='A_-2', xy=(0.008, -7.500), node_id=11,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 12: A_{-1}
graph.addnode(label='A_{-1}', xy=(1.741, -6.500), node_id=12,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 13: A_0
graph.addnode(label='A_0', xy=(3.473, -5.500), node_id=13,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 14: A_1
graph.addnode(label='A_1', xy=(5.205, -4.500), node_id=14,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 15: A_2
graph.addnode(label='A_2', xy=(6.937, -3.500), node_id=15,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Add edges
# Edge 1: A_2 → A_2
graph.addedge(fromnode_id=5, tonode_id=10,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 2: A_2 → A_1
graph.addedge(fromnode_id=5, tonode_id=9,
             label=[None, None],
             labeltheta=17.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 3: A_2 → A_0
graph.addedge(fromnode_id=5, tonode_id=8,
             label=[None, None],
             labeltheta=8.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 4: A_2 → A_{-1}
graph.addedge(fromnode_id=5, tonode_id=7,
             label=[None, None],
             labeltheta=2.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 5: A_-2 → A_2
graph.addedge(fromnode_id=6, tonode_id=5,
             label=[None, None],
             labeltheta=177.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 6: A_2 → A_2
graph.addedge(fromnode_id=15, tonode_id=5,
             label=[None, None],
             labeltheta=150.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 7: A_1 → A_2
graph.addedge(fromnode_id=14, tonode_id=5,
             label=[None, None],
             labeltheta=142.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 8: A_0 → A_2
graph.addedge(fromnode_id=13, tonode_id=5,
             label=[None, None],
             labeltheta=135.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 9: A_{-1} → A_2
graph.addedge(fromnode_id=12, tonode_id=5,
             label=[None, None],
             labeltheta=126.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 10: A_-2 → A_2
graph.addedge(fromnode_id=11, tonode_id=5,
             label=[None, None],
             labeltheta=117.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 11: A_1 → A_2
graph.addedge(fromnode_id=4, tonode_id=10,
             label=[None, None],
             labeltheta=42.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 12: A_1 → A_1
graph.addedge(fromnode_id=4, tonode_id=9,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 13: A_1 → A_0
graph.addedge(fromnode_id=4, tonode_id=8,
             label=[None, None],
             labeltheta=20.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 14: A_1 → A_{-1}
graph.addedge(fromnode_id=4, tonode_id=7,
             label=[None, None],
             labeltheta=12.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 15: A_1 → A_-2
graph.addedge(fromnode_id=4, tonode_id=6,
             label=[None, None],
             labeltheta=6.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 16: A_1 → A_2
graph.addedge(fromnode_id=4, tonode_id=15,
             label=[None, None],
             labeltheta=-22.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 17: A_1 → A_1
graph.addedge(fromnode_id=4, tonode_id=14,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 18: A_1 → A_0
graph.addedge(fromnode_id=4, tonode_id=13,
             label=[None, None],
             labeltheta=-38.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 19: A_1 → A_{-1}
graph.addedge(fromnode_id=4, tonode_id=12,
             label=[None, None],
             labeltheta=-47.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 20: A_1 → A_-2
graph.addedge(fromnode_id=4, tonode_id=11,
             label=[None, None],
             labeltheta=-57.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 21: A_0 → A_2
graph.addedge(fromnode_id=3, tonode_id=10,
             label=[None, None],
             labeltheta=51.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 22: A_0 → A_1
graph.addedge(fromnode_id=3, tonode_id=9,
             label=[None, None],
             labeltheta=39.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 23: A_0 → A_0
graph.addedge(fromnode_id=3, tonode_id=8,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 24: A_0 → A_{-1}
graph.addedge(fromnode_id=3, tonode_id=7,
             label=[None, None],
             labeltheta=21.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 25: A_0 → A_-2
graph.addedge(fromnode_id=3, tonode_id=6,
             label=[None, None],
             labeltheta=15.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 26: A_0 → A_2
graph.addedge(fromnode_id=3, tonode_id=15,
             label=[None, None],
             labeltheta=-15.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 27: A_0 → A_1
graph.addedge(fromnode_id=3, tonode_id=14,
             label=[None, None],
             labeltheta=-21.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 28: A_0 → A_0
graph.addedge(fromnode_id=3, tonode_id=13,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 29: A_0 → A_{-1}
graph.addedge(fromnode_id=3, tonode_id=12,
             label=[None, None],
             labeltheta=-39.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 30: A_0 → A_-2
graph.addedge(fromnode_id=3, tonode_id=11,
             label=[None, None],
             labeltheta=-51.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 31: A_{-1} → A_2
graph.addedge(fromnode_id=2, tonode_id=10,
             label=[None, None],
             labeltheta=57.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 32: A_{-1} → A_1
graph.addedge(fromnode_id=2, tonode_id=9,
             label=[None, None],
             labeltheta=47.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 33: A_{-1} → A_0
graph.addedge(fromnode_id=2, tonode_id=8,
             label=[None, None],
             labeltheta=38.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 34: A_{-1} → A_{-1}
graph.addedge(fromnode_id=2, tonode_id=7,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 35: A_{-1} → A_-2
graph.addedge(fromnode_id=2, tonode_id=6,
             label=[None, None],
             labeltheta=22.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 36: A_{-1} → A_2
graph.addedge(fromnode_id=2, tonode_id=15,
             label=[None, None],
             labeltheta=-6.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 37: A_{-1} → A_1
graph.addedge(fromnode_id=2, tonode_id=14,
             label=[None, None],
             labeltheta=-12.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 38: A_{-1} → A_0
graph.addedge(fromnode_id=2, tonode_id=13,
             label=[None, None],
             labeltheta=-20.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 39: A_{-1} → A_{-1}
graph.addedge(fromnode_id=2, tonode_id=12,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 40: A_-2 → A_2
graph.addedge(fromnode_id=1, tonode_id=10,
             label=[None, None],
             labeltheta=62.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 41: A_-2 → A_1
graph.addedge(fromnode_id=1, tonode_id=9,
             label=[None, None],
             labeltheta=53.4,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 42: A_-2 → A_0
graph.addedge(fromnode_id=1, tonode_id=8,
             label=[None, None],
             labeltheta=44.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 43: A_-2 → A_{-1}
graph.addedge(fromnode_id=1, tonode_id=7,
             label=[None, None],
             labeltheta=37.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 44: A_-2 → A_-2
graph.addedge(fromnode_id=1, tonode_id=6,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 45: A_-2 → A_2
graph.addedge(fromnode_id=1, tonode_id=15,
             label=[None, None],
             labeltheta=2.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 46: A_-2 → A_1
graph.addedge(fromnode_id=1, tonode_id=14,
             label=[None, None],
             labeltheta=-2.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 47: A_-2 → A_0
graph.addedge(fromnode_id=1, tonode_id=13,
             label=[None, None],
             labeltheta=-8.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 48: A_-2 → A_{-1}
graph.addedge(fromnode_id=1, tonode_id=12,
             label=[None, None],
             labeltheta=-17.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 49: A_-2 → A_-2
graph.addedge(fromnode_id=1, tonode_id=11,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})


# Ports, transmission lines and their wiring
graph.addport(label='P1', xy=(-12.982, 0.000), R=0.600, port_id=1, autoorient=True, fill='#aab6a8', labelcolor='#ffffff')
graph.addport(label='P1+', xy=(6.937, 11.500), R=0.600, port_id=3, autoorient=True, fill='#929ec0', labelcolor='#ffffff')
graph.addport(label='P1-', xy=(6.937, -10.500), R=0.600, port_id=4, autoorient=True, fill='#cd726c', labelcolor='#ffffff')

graph.addwire(start=('port', 1), end=('node', 5))
graph.addwire(start=('port', 1), end=('node', 4))
graph.addwire(start=('port', 1), end=('node', 3))
graph.addwire(start=('port', 1), end=('node', 2))
graph.addwire(start=('port', 1), end=('node', 1))
graph.addwire(start=('port', 3), end=('node', 10))
graph.addwire(start=('port', 3), end=('node', 9))
graph.addwire(start=('port', 3), end=('node', 8))
graph.addwire(start=('port', 3), end=('node', 7))
graph.addwire(start=('port', 3), end=('node', 6))
graph.addwire(start=('port', 4), end=('node', 15))
graph.addwire(start=('port', 4), end=('node', 14))
graph.addwire(start=('port', 4), end=('node', 13))
graph.addwire(start=('port', 4), end=('node', 12))
graph.addwire(start=('port', 4), end=('node', 11))


# Draw the graph
# overfrac adds padding around the graph to ensure all elements are visible
# Increase overfrac if labels or self-loops are cut off
graph.draw(figsize=12, overfrac=0.2)

plt.axis('off')
plt.title('')  # Remove title
plt.show()

# %%
#!/usr/bin/env python
"""
Generated graph code using graph_primitives
"""

import matplotlib.pyplot as plt
import graphulator.graph_primitives as gp
import graphulator.graphulator_config as config

# Create graph circuit (allow duplicate labels)
# Set use_latex=True for LaTeX rendering, False for MathText (default)
graph = gp.GraphCircuit(allow_duplicate_labels=True, use_latex=False)

# Add nodes
# Node 1: A_-2
graph.addnode(label='A_-2', xy=(-6.054, -4.000), node_id=1,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 2: A_{-1}
graph.addnode(label='A_{-1}', xy=(-6.054, -2.000), node_id=2,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 3: A_0
graph.addnode(label='A_0', xy=(-6.054, -0.000), node_id=3,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 4: A_1
graph.addnode(label='A_1', xy=(-6.054, 2.000), node_id=4,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 5: A_2
graph.addnode(label='A_2', xy=(-6.054, 4.000), node_id=5,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 6: A_-2
graph.addnode(label='A_-2', xy=(6.937, 3.500), node_id=6,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 7: A_{-1}
graph.addnode(label='A_{-1}', xy=(5.205, 4.500), node_id=7,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 8: A_0
graph.addnode(label='A_0', xy=(3.473, 5.500), node_id=8,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 9: A_1
graph.addnode(label='A_1', xy=(1.741, 6.500), node_id=9,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 10: A_2
graph.addnode(label='A_2', xy=(0.008, 7.500), node_id=10,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 11: A_-2
graph.addnode(label='A_-2', xy=(0.008, -7.500), node_id=11,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 12: A_{-1}
graph.addnode(label='A_{-1}', xy=(1.741, -6.500), node_id=12,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 13: A_0
graph.addnode(label='A_0', xy=(3.473, -5.500), node_id=13,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 14: A_1
graph.addnode(label='A_1', xy=(5.205, -4.500), node_id=14,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 15: A_2
graph.addnode(label='A_2', xy=(6.937, -3.500), node_id=15,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Add edges
# Edge 1: A_2 → A_2
graph.addedge(fromnode_id=5, tonode_id=10,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 10.4, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 2: A_2 → A_1
graph.addedge(fromnode_id=5, tonode_id=9,
             label=[None, None],
             labeltheta=17.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 10.4, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 3: A_2 → A_0
graph.addedge(fromnode_id=5, tonode_id=8,
             label=[None, None],
             labeltheta=8.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 10.4, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 4: A_2 → A_{-1}
graph.addedge(fromnode_id=5, tonode_id=7,
             label=[None, None],
             labeltheta=2.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 5: A_-2 → A_2
graph.addedge(fromnode_id=6, tonode_id=5,
             label=[None, None],
             labeltheta=177.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 6: A_2 → A_2
graph.addedge(fromnode_id=15, tonode_id=5,
             label=[None, None],
             labeltheta=150.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 7: A_1 → A_2
graph.addedge(fromnode_id=14, tonode_id=5,
             label=[None, None],
             labeltheta=142.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 8: A_0 → A_2
graph.addedge(fromnode_id=13, tonode_id=5,
             label=[None, None],
             labeltheta=135.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 9: A_{-1} → A_2
graph.addedge(fromnode_id=12, tonode_id=5,
             label=[None, None],
             labeltheta=126.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 10: A_-2 → A_2
graph.addedge(fromnode_id=11, tonode_id=5,
             label=[None, None],
             labeltheta=117.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 11: A_1 → A_2
graph.addedge(fromnode_id=4, tonode_id=10,
             label=[None, None],
             labeltheta=42.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 12: A_1 → A_1
graph.addedge(fromnode_id=4, tonode_id=9,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 13: A_1 → A_0
graph.addedge(fromnode_id=4, tonode_id=8,
             label=[None, None],
             labeltheta=20.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 14: A_1 → A_{-1}
graph.addedge(fromnode_id=4, tonode_id=7,
             label=[None, None],
             labeltheta=12.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 15: A_1 → A_-2
graph.addedge(fromnode_id=4, tonode_id=6,
             label=[None, None],
             labeltheta=6.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 16: A_1 → A_2
graph.addedge(fromnode_id=4, tonode_id=15,
             label=[None, None],
             labeltheta=-22.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 17: A_1 → A_1
graph.addedge(fromnode_id=4, tonode_id=14,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 18: A_1 → A_0
graph.addedge(fromnode_id=4, tonode_id=13,
             label=[None, None],
             labeltheta=-38.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 19: A_1 → A_{-1}
graph.addedge(fromnode_id=4, tonode_id=12,
             label=[None, None],
             labeltheta=-47.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 20: A_1 → A_-2
graph.addedge(fromnode_id=4, tonode_id=11,
             label=[None, None],
             labeltheta=-57.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 21: A_0 → A_2
graph.addedge(fromnode_id=3, tonode_id=10,
             label=[None, None],
             labeltheta=51.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 22: A_0 → A_1
graph.addedge(fromnode_id=3, tonode_id=9,
             label=[None, None],
             labeltheta=39.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 23: A_0 → A_0
graph.addedge(fromnode_id=3, tonode_id=8,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 24: A_0 → A_{-1}
graph.addedge(fromnode_id=3, tonode_id=7,
             label=[None, None],
             labeltheta=21.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 25: A_0 → A_-2
graph.addedge(fromnode_id=3, tonode_id=6,
             label=[None, None],
             labeltheta=15.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 26: A_0 → A_2
graph.addedge(fromnode_id=3, tonode_id=15,
             label=[None, None],
             labeltheta=-15.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 27: A_0 → A_1
graph.addedge(fromnode_id=3, tonode_id=14,
             label=[None, None],
             labeltheta=-21.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 28: A_0 → A_0
graph.addedge(fromnode_id=3, tonode_id=13,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 29: A_0 → A_{-1}
graph.addedge(fromnode_id=3, tonode_id=12,
             label=[None, None],
             labeltheta=-39.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 30: A_0 → A_-2
graph.addedge(fromnode_id=3, tonode_id=11,
             label=[None, None],
             labeltheta=-51.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 31: A_{-1} → A_2
graph.addedge(fromnode_id=2, tonode_id=10,
             label=[None, None],
             labeltheta=57.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 32: A_{-1} → A_1
graph.addedge(fromnode_id=2, tonode_id=9,
             label=[None, None],
             labeltheta=47.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 33: A_{-1} → A_0
graph.addedge(fromnode_id=2, tonode_id=8,
             label=[None, None],
             labeltheta=38.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 34: A_{-1} → A_{-1}
graph.addedge(fromnode_id=2, tonode_id=7,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 35: A_{-1} → A_-2
graph.addedge(fromnode_id=2, tonode_id=6,
             label=[None, None],
             labeltheta=22.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 36: A_{-1} → A_2
graph.addedge(fromnode_id=2, tonode_id=15,
             label=[None, None],
             labeltheta=-6.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 37: A_{-1} → A_1
graph.addedge(fromnode_id=2, tonode_id=14,
             label=[None, None],
             labeltheta=-12.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 38: A_{-1} → A_0
graph.addedge(fromnode_id=2, tonode_id=13,
             label=[None, None],
             labeltheta=-20.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 39: A_{-1} → A_{-1}
graph.addedge(fromnode_id=2, tonode_id=12,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 40: A_-2 → A_2
graph.addedge(fromnode_id=1, tonode_id=10,
             label=[None, None],
             labeltheta=62.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 41: A_-2 → A_1
graph.addedge(fromnode_id=1, tonode_id=9,
             label=[None, None],
             labeltheta=53.4,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 42: A_-2 → A_0
graph.addedge(fromnode_id=1, tonode_id=8,
             label=[None, None],
             labeltheta=44.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 43: A_-2 → A_{-1}
graph.addedge(fromnode_id=1, tonode_id=7,
             label=[None, None],
             labeltheta=37.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 44: A_-2 → A_-2
graph.addedge(fromnode_id=1, tonode_id=6,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 45: A_-2 → A_2
graph.addedge(fromnode_id=1, tonode_id=15,
             label=[None, None],
             labeltheta=2.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 46: A_-2 → A_1
graph.addedge(fromnode_id=1, tonode_id=14,
             label=[None, None],
             labeltheta=-2.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 47: A_-2 → A_0
graph.addedge(fromnode_id=1, tonode_id=13,
             label=[None, None],
             labeltheta=-8.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 48: A_-2 → A_{-1}
graph.addedge(fromnode_id=1, tonode_id=12,
             label=[None, None],
             labeltheta=-17.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 49: A_-2 → A_-2
graph.addedge(fromnode_id=1, tonode_id=11,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})


# Ports, transmission lines and their wiring
graph.addport(label='P1', xy=(-12.982, 0.000), R=0.600, port_id=1, autoorient=True, fill='#aab6a8', labelcolor='#ffffff')
graph.addport(label='P1+', xy=(6.937, 11.500), R=0.600, port_id=3, autoorient=True, fill='#929ec0', labelcolor='#ffffff')
graph.addport(label='P1-', xy=(6.937, -10.500), R=0.600, port_id=4, autoorient=True, fill='#cd726c', labelcolor='#ffffff')
graph.addwire(start=('port', 1), end=('node', 5))
graph.addwire(start=('port', 1), end=('node', 4))
graph.addwire(start=('port', 1), end=('node', 3))
graph.addwire(start=('port', 1), end=('node', 2))
graph.addwire(start=('port', 1), end=('node', 1))
graph.addwire(start=('port', 3), end=('node', 10))
graph.addwire(start=('port', 3), end=('node', 9))
graph.addwire(start=('port', 3), end=('node', 8))
graph.addwire(start=('port', 3), end=('node', 7))
graph.addwire(start=('port', 3), end=('node', 6))
graph.addwire(start=('port', 4), end=('node', 15))
graph.addwire(start=('port', 4), end=('node', 14))
graph.addwire(start=('port', 4), end=('node', 13))
graph.addwire(start=('port', 4), end=('node', 12))
graph.addwire(start=('port', 4), end=('node', 11))


# Draw the graph
# overfrac adds padding around the graph to ensure all elements are visible
# Increase overfrac if labels or self-loops are cut off
graph.draw(figsize=12, overfrac=0.2)

plt.axis('off')
plt.title('')  # Remove title
plt.show()

# %%
#!/usr/bin/env python
"""
Generated graph code using graph_primitives
"""

import matplotlib.pyplot as plt
import graphulator.graph_primitives as gp
import graphulator.graphulator_config as config

# Create graph circuit (allow duplicate labels)
# Set use_latex=True for LaTeX rendering, False for MathText (default)
graph = gp.GraphCircuit(allow_duplicate_labels=True, use_latex=False)

# Add nodes
# Node 1: A_-2
graph.addnode(label='A_-2', xy=(-6.054, -4.000), node_id=1,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 2: A_{-1}
graph.addnode(label='A_{-1}', xy=(-6.054, -2.000), node_id=2,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 3: A_0
graph.addnode(label='A_0', xy=(-6.054, -0.000), node_id=3,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 4: A_1
graph.addnode(label='A_1', xy=(-6.054, 2.000), node_id=4,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 5: A_2
graph.addnode(label='A_2', xy=(-6.054, 4.000), node_id=5,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 6: A_-2
graph.addnode(label='A_-2', xy=(6.937, 3.500), node_id=6,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 7: A_{-1}
graph.addnode(label='A_{-1}', xy=(5.205, 4.500), node_id=7,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 8: A_0
graph.addnode(label='A_0', xy=(3.473, 5.500), node_id=8,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 9: A_1
graph.addnode(label='A_1', xy=(1.741, 6.500), node_id=9,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 10: A_2
graph.addnode(label='A_2', xy=(0.008, 7.500), node_id=10,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 11: A_-2
graph.addnode(label='A_-2', xy=(0.008, -7.500), node_id=11,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 12: A_{-1}
graph.addnode(label='A_{-1}', xy=(1.741, -6.500), node_id=12,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 13: A_0
graph.addnode(label='A_0', xy=(3.473, -5.500), node_id=13,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 14: A_1
graph.addnode(label='A_1', xy=(5.205, -4.500), node_id=14,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Node 15: A_2
graph.addnode(label='A_2', xy=(6.937, -3.500), node_id=15,
             nodecolor=config.MYCOLORS['RED'],
             R=0.600,
             fontscale=1.050,
             conj=False,
             drawselfloop=False)

# Add edges
# Edge 1: A_2 → A_2
graph.addedge(fromnode_id=5, tonode_id=10,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 10.4, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 2: A_2 → A_1
graph.addedge(fromnode_id=5, tonode_id=9,
             label=[None, None],
             labeltheta=17.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 10.4, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 3: A_2 → A_0
graph.addedge(fromnode_id=5, tonode_id=8,
             label=[None, None],
             labeltheta=8.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 10.4, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 4: A_2 → A_{-1}
graph.addedge(fromnode_id=5, tonode_id=7,
             label=[None, None],
             labeltheta=2.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 5: A_-2 → A_2
graph.addedge(fromnode_id=6, tonode_id=5,
             label=[None, None],
             labeltheta=177.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 6: A_2 → A_2
graph.addedge(fromnode_id=15, tonode_id=5,
             label=[None, None],
             labeltheta=150.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 7: A_1 → A_2
graph.addedge(fromnode_id=14, tonode_id=5,
             label=[None, None],
             labeltheta=142.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 8: A_0 → A_2
graph.addedge(fromnode_id=13, tonode_id=5,
             label=[None, None],
             labeltheta=135.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 9: A_{-1} → A_2
graph.addedge(fromnode_id=12, tonode_id=5,
             label=[None, None],
             labeltheta=126.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 10: A_-2 → A_2
graph.addedge(fromnode_id=11, tonode_id=5,
             label=[None, None],
             labeltheta=117.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 11: A_1 → A_2
graph.addedge(fromnode_id=4, tonode_id=10,
             label=[None, None],
             labeltheta=42.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 12: A_1 → A_1
graph.addedge(fromnode_id=4, tonode_id=9,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 13: A_1 → A_0
graph.addedge(fromnode_id=4, tonode_id=8,
             label=[None, None],
             labeltheta=20.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 14: A_1 → A_{-1}
graph.addedge(fromnode_id=4, tonode_id=7,
             label=[None, None],
             labeltheta=12.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 15: A_1 → A_-2
graph.addedge(fromnode_id=4, tonode_id=6,
             label=[None, None],
             labeltheta=6.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 16: A_1 → A_2
graph.addedge(fromnode_id=4, tonode_id=15,
             label=[None, None],
             labeltheta=-22.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 17: A_1 → A_1
graph.addedge(fromnode_id=4, tonode_id=14,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 18: A_1 → A_0
graph.addedge(fromnode_id=4, tonode_id=13,
             label=[None, None],
             labeltheta=-38.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 19: A_1 → A_{-1}
graph.addedge(fromnode_id=4, tonode_id=12,
             label=[None, None],
             labeltheta=-47.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 20: A_1 → A_-2
graph.addedge(fromnode_id=4, tonode_id=11,
             label=[None, None],
             labeltheta=-57.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 21: A_0 → A_2
graph.addedge(fromnode_id=3, tonode_id=10,
             label=[None, None],
             labeltheta=51.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 22: A_0 → A_1
graph.addedge(fromnode_id=3, tonode_id=9,
             label=[None, None],
             labeltheta=39.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 23: A_0 → A_0
graph.addedge(fromnode_id=3, tonode_id=8,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 24: A_0 → A_{-1}
graph.addedge(fromnode_id=3, tonode_id=7,
             label=[None, None],
             labeltheta=21.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 25: A_0 → A_-2
graph.addedge(fromnode_id=3, tonode_id=6,
             label=[None, None],
             labeltheta=15.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 26: A_0 → A_2
graph.addedge(fromnode_id=3, tonode_id=15,
             label=[None, None],
             labeltheta=-15.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 27: A_0 → A_1
graph.addedge(fromnode_id=3, tonode_id=14,
             label=[None, None],
             labeltheta=-21.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 28: A_0 → A_0
graph.addedge(fromnode_id=3, tonode_id=13,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 29: A_0 → A_{-1}
graph.addedge(fromnode_id=3, tonode_id=12,
             label=[None, None],
             labeltheta=-39.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 30: A_0 → A_-2
graph.addedge(fromnode_id=3, tonode_id=11,
             label=[None, None],
             labeltheta=-51.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 31: A_{-1} → A_2
graph.addedge(fromnode_id=2, tonode_id=10,
             label=[None, None],
             labeltheta=57.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 32: A_{-1} → A_1
graph.addedge(fromnode_id=2, tonode_id=9,
             label=[None, None],
             labeltheta=47.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 33: A_{-1} → A_0
graph.addedge(fromnode_id=2, tonode_id=8,
             label=[None, None],
             labeltheta=38.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 34: A_{-1} → A_{-1}
graph.addedge(fromnode_id=2, tonode_id=7,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 35: A_{-1} → A_-2
graph.addedge(fromnode_id=2, tonode_id=6,
             label=[None, None],
             labeltheta=22.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 36: A_{-1} → A_2
graph.addedge(fromnode_id=2, tonode_id=15,
             label=[None, None],
             labeltheta=-6.6,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 37: A_{-1} → A_1
graph.addedge(fromnode_id=2, tonode_id=14,
             label=[None, None],
             labeltheta=-12.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 38: A_{-1} → A_0
graph.addedge(fromnode_id=2, tonode_id=13,
             label=[None, None],
             labeltheta=-20.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 39: A_{-1} → A_{-1}
graph.addedge(fromnode_id=2, tonode_id=12,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 40: A_-2 → A_2
graph.addedge(fromnode_id=1, tonode_id=10,
             label=[None, None],
             labeltheta=62.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 41: A_-2 → A_1
graph.addedge(fromnode_id=1, tonode_id=9,
             label=[None, None],
             labeltheta=53.4,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 42: A_-2 → A_0
graph.addedge(fromnode_id=1, tonode_id=8,
             label=[None, None],
             labeltheta=44.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 43: A_-2 → A_{-1}
graph.addedge(fromnode_id=1, tonode_id=7,
             label=[None, None],
             labeltheta=37.1,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 44: A_-2 → A_-2
graph.addedge(fromnode_id=1, tonode_id=6,
             label=[None, None],
             labeltheta=30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 45: A_-2 → A_2
graph.addedge(fromnode_id=1, tonode_id=15,
             label=[None, None],
             labeltheta=2.2,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 46: A_-2 → A_1
graph.addedge(fromnode_id=1, tonode_id=14,
             label=[None, None],
             labeltheta=-2.5,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 47: A_-2 → A_0
graph.addedge(fromnode_id=1, tonode_id=13,
             label=[None, None],
             labeltheta=-8.9,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 48: A_-2 → A_{-1}
graph.addedge(fromnode_id=1, tonode_id=12,
             label=[None, None],
             labeltheta=-17.8,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})

# Edge 49: A_-2 → A_-2
graph.addedge(fromnode_id=1, tonode_id=11,
             label=[None, None],
             labeltheta=-30.0,
             labeloffset=1.8,
             labelfontsize=24,
             style='double',
             whichedges='both',
             theta=20,
             loopkwargs={'lw': 17.3, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900})


# Ports, transmission lines and their wiring
graph.addport(label='P1', xy=(-12.982, 0.000), R=0.600, port_id=1, autoorient=True, fill='#aab6a8', labelcolor='#ffffff')
graph.addport(label='P1+', xy=(0.875, 12.000), R=0.600, port_id=3, angle=0.0, length=1.100, fill='#929ec0', labelcolor='#ffffff')
graph.addport(label='P1-', xy=(0.714, -11.526), R=0.600, port_id=4, angle=0.0, length=1.100, fill='#cd726c', labelcolor='#ffffff')
graph.addwire(start=('port', 1), end=('node', 5))
graph.addwire(start=('port', 1), end=('node', 4))
graph.addwire(start=('port', 1), end=('node', 3))
graph.addwire(start=('port', 1), end=('node', 2))
graph.addwire(start=('port', 1), end=('node', 1))
graph.addwire(start=('port', 3), end=('node', 10))
graph.addwire(start=('port', 3), end=('node', 9))
graph.addwire(start=('port', 3), end=('node', 8))
graph.addwire(start=('port', 3), end=('node', 7))
graph.addwire(start=('port', 3), end=('node', 6))
graph.addwire(start=('port', 4), end=('node', 15))
graph.addwire(start=('port', 4), end=('node', 14))
graph.addwire(start=('port', 4), end=('node', 13))
graph.addwire(start=('port', 4), end=('node', 12))
graph.addwire(start=('port', 4), end=('node', 11))


# Draw the graph
# overfrac adds padding around the graph to ensure all elements are visible
# Increase overfrac if labels or self-loops are cut off
graph.draw(figsize=12, overfrac=0.2)

plt.axis('off')
plt.title('')  # Remove title
plt.show()

# %% [markdown]
# ## Grouped-by-style export test
# ***092326***

# %%
#!/usr/bin/env python
"""
Generated graph code using graph_primitives

Objects are grouped by style: each entry in a *_STYLES
dict is one appearance, and the matching list holds the
geometry drawn in it. Edit a style to restyle every object
using it, or build the lists programmatically.
"""

import matplotlib.pyplot as plt
import graphulator.graph_primitives as gp
import graphulator.graphulator_config as config

# Create graph circuit (allow duplicate labels)
# Set use_latex=True for LaTeX rendering, False for MathText (default)
graph = gp.GraphCircuit(allow_duplicate_labels=True, use_latex=False)

# Nodes by style. Edit one entry here and every node drawn in it follows.
NODE_STYLES = {
    # 5 nodes: A_-2, A_{-1}, A_0, A_1, A_2
    'node1': dict(nodecolor='#aab6a8', R=0.600, fontscale=1.050, conj=False,
                  drawselfloop=False),
    # 5 nodes: A_-2, A_{-1}, A_0, A_1, A_2
    'node2': dict(nodecolor='#929ec0', R=0.600, fontscale=1.050, conj=False,
                  drawselfloop=False),
    # 5 nodes: A_-2, A_{-1}, A_0, A_1, A_2
    'node3': dict(nodecolor='#cd726c', R=0.600, fontscale=1.050, conj=False,
                  drawselfloop=False),
}

# (label, xy, node_id) per style
NODES = {
    'node1': [
        ('A_-2', (-6.054, -4.000), 1),
        ('A_{-1}', (-6.054, -2.000), 2),
        ('A_0', (-6.054, -0.000), 3),
        ('A_1', (-6.054, 2.000), 4),
        ('A_2', (-6.054, 4.000), 5),
    ],
    'node2': [
        ('A_-2', (6.937, 3.500), 6),
        ('A_{-1}', (5.205, 4.500), 7),
        ('A_0', (3.473, 5.500), 8),
        ('A_1', (1.741, 6.500), 9),
        ('A_2', (0.008, 7.500), 10),
    ],
    'node3': [
        ('A_-2', (0.008, -7.500), 11),
        ('A_{-1}', (1.741, -6.500), 12),
        ('A_0', (3.473, -5.500), 13),
        ('A_1', (5.205, -4.500), 14),
        ('A_2', (6.937, -3.500), 15),
    ],
}

for _style, _items in NODES.items():
    for _label, _xy, _node_id in _items:
        graph.addnode(label=_label, xy=_xy, node_id=_node_id,
                      **NODE_STYLES[_style])

# Edges by style. Edit one entry here and every edge drawn in it follows.
EDGE_STYLES = {
    # 3 edges: A_2→A_2, A_2→A_1, A_2→A_0
    'double1': dict(labeloffset=1.8, labelfontsize=24, style='double',
                    whichedges='both', theta=20,
                    loopkwargs={'lw': 2, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900}),
}

# (fromnode_id, tonode_id) per style
EDGES = {
    'double1': [
        (5, 10),
        (5, 9),
        (5, 8),
        (5, 7),
        (6, 5),
        (15, 5),
        (14, 5),
        (13, 5),
        (12, 5),
        (11, 5),
        (4, 10),
        (4, 9),
        (4, 8),
        (4, 7),
        (4, 6),
        (4, 15),
        (4, 14),
        (4, 13),
        (4, 12),
        (4, 11),
        (3, 10),
        (3, 9),
        (3, 8),
        (3, 7),
        (3, 6),
        (3, 15),
        (3, 14),
        (3, 13),
        (3, 12),
        (3, 11),
        (2, 10),
        (2, 9),
        (2, 8),
        (2, 7),
        (2, 6),
        (2, 15),
        (2, 14),
        (2, 13),
        (2, 12),
        (1, 10),
        (1, 9),
        (1, 8),
        (1, 7),
        (1, 6),
        (1, 15),
        (1, 14),
        (1, 13),
        (1, 12),
        (1, 11),
    ],
}

for _style, _items in EDGES.items():
    for _fromnode_id, _tonode_id in _items:
        graph.addedge(fromnode_id=_fromnode_id, tonode_id=_tonode_id,
                      **EDGE_STYLES[_style])


# Ports, transmission lines and their wiring
# Ports by style. Edit one entry here and every port drawn in it follows.
PORT_STYLES = {
    # 1 port: P1
    'port1': dict(R=0.600, fill='#aab6a8', labelcolor='#ffffff'),
    # 1 port: P1+
    'port2': dict(R=0.600, length=1.100, fill='#929ec0', labelcolor='#ffffff'),
    # 1 port: P1-
    'port3': dict(R=0.600, length=1.100, fill='#cd726c', labelcolor='#ffffff'),
}

# (label, xy, port_id, overrides) per style -- overrides is a dict of per-port keywords
PORTS = {
    'port1': [
        ('P1', (-12.982, 0.000), 1, dict(autoorient=True)),
    ],
    'port2': [
        ('P1+', (0.875, 12.000), 3, dict(angle=0.0)),
    ],
    'port3': [
        ('P1-', (0.714, -11.526), 4, dict(angle=0.0)),
    ],
}

for _style, _items in PORTS.items():
    for _label, _xy, _port_id, _over in _items:
        graph.addport(label=_label, xy=_xy, port_id=_port_id,
                      **PORT_STYLES[_style], **_over)

# Wires by style. Edit one entry here and every wire drawn in it follows.
WIRE_STYLES = {
    # 15 wires
    'wire': dict(),
}

# (start, end) per style
WIRES = {
    'wire': [
        (('port', 1), ('node', 5)),
        (('port', 1), ('node', 4)),
        (('port', 1), ('node', 3)),
        (('port', 1), ('node', 2)),
        (('port', 1), ('node', 1)),
        (('port', 3), ('node', 10)),
        (('port', 3), ('node', 9)),
        (('port', 3), ('node', 8)),
        (('port', 3), ('node', 7)),
        (('port', 3), ('node', 6)),
        (('port', 4), ('node', 15)),
        (('port', 4), ('node', 14)),
        (('port', 4), ('node', 13)),
        (('port', 4), ('node', 12)),
        (('port', 4), ('node', 11)),
    ],
}

for _style, _items in WIRES.items():
    for _start, _end in _items:
        graph.addwire(start=_start, end=_end, **WIRE_STYLES[_style])

# Draw the graph
# overfrac adds padding around the graph to ensure all elements are visible
# Increase overfrac if labels or self-loops are cut off
graph.draw(figsize=12, overfrac=0.2)

plt.axis('off')
plt.title('')  # Remove title
plt.show()

# %% [markdown]
# ### try to program the placement and connections

# %%
#!/usr/bin/env python
"""
Generated graph code using graph_primitives

Objects are grouped by style: each entry in a *_STYLES
dict is one appearance, and the matching list holds the
geometry drawn in it. Edit a style to restyle every object
using it, or build the lists programmatically.
"""

import matplotlib.pyplot as plt
import graphulator.graph_primitives as gp
import graphulator.graphulator_config as config
import math

# Create graph circuit (allow duplicate labels)
# Set use_latex=True for LaTeX rendering, False for MathText (default)
graph = gp.GraphCircuit(allow_duplicate_labels=True, use_latex=False)

# Nodes by style. Edit one entry here and every node drawn in it follows.
NODE_STYLES = {
    # 5 nodes: A_-2, A_{-1}, A_0, A_1, A_2
    'node1': dict(nodecolor='#aab6a8', R=0.600, fontscale=1.050, conj=False,
                  drawselfloop=False),
    # 5 nodes: A_-2, A_{-1}, A_0, A_1, A_2
    'node2': dict(nodecolor='#929ec0', R=0.600, fontscale=1.050, conj=False,
                  drawselfloop=False),
    # 5 nodes: A_-2, A_{-1}, A_0, A_1, A_2
    'node3': dict(nodecolor='#cd726c', R=0.600, fontscale=1.050, conj=False,
                  drawselfloop=False),
}

# (label, xy, node_id) per style
# NODES = {
#     'node1': [
#         ('A_-2', (-6.054, -4.000), 1),
#         ('A_{-1}', (-6.054, -2.000), 2),
#         ('A_0', (-6.054, -0.000), 3),
#         ('A_1', (-6.054, 2.000), 4),
#         ('A_2', (-6.054, 4.000), 5),
#     ],
#     'node2': [
#         ('A_-2', (6.937, 3.500), 6),
#         ('A_{-1}', (5.205, 4.500), 7),
#         ('A_0', (3.473, 5.500), 8),
#         ('A_1', (1.741, 6.500), 9),
#         ('A_2', (0.008, 7.500), 10),
#     ],
#     'node3': [
#         ('A_-2', (0.008, -7.500), 11),
#         ('A_{-1}', (1.741, -6.500), 12),
#         ('A_0', (3.473, -5.500), 13),
#         ('A_1', (5.205, -4.500), 14),
#         ('A_2', (6.937, -3.500), 15),
#     ],
# }

Nm = 4 # number of modes on either side of zero
R  = 32 # circle that mode is placed in in arb grid units
dtheta_deg = 4
current_nodeID = 1

def create_circle_node_dict(
          xycenter=0,  # center of the node circle
          R=16,        # radius
          dtheta_deg = 15,  # angular separation between nodes
          theta_rot_deg = 60, # rotate all of the nodes in the circle by this angle in degrees
          node_prefix='A' # prefix for node labels
          ):
    global current_nodeID

    node_tuple_list = []
    for m in range(-Nm, Nm+1):
        theta = math.radians(theta_rot_deg + m * dtheta_deg)
        x = xycenter[0] + R * math.cos(theta)
        y = xycenter[1] + R * math.sin(theta)
        node_label = f'{node_prefix}_{m}'
        node_tuple = (node_label, (x, y), current_nodeID)
        node_tuple_list.append(node_tuple)

        current_nodeID += 1

    return node_tuple_list

# put the big circle centers at the vertices of a triangle with sidelength 2R + some margin
circle_margin = 4

# define the coordinates of the triangle vertices for the circle centers with overall rotation theta_triangle
theta_triangle = -30  # overall rotation of the triangle in degrees
XY = [
    (0, 0),
    (2*R + circle_margin, 0),
    (R + circle_margin/2, (2*R + circle_margin) * math.sin(math.radians(60)))
]
# apply overall rotation of the triangle
XY = [
    (
        math.cos(math.radians(theta_triangle)) * x - math.sin(math.radians(theta_triangle)) * y,
        math.sin(math.radians(theta_triangle)) * x + math.cos(math.radians(theta_triangle)) * y
    )
    for x, y in XY
]

NODES = {
    'node1': create_circle_node_dict(xycenter=XY[0], R=R, dtheta_deg=dtheta_deg, theta_rot_deg=0, node_prefix='A'),
    'node2': create_circle_node_dict(xycenter=XY[2], R=R, dtheta_deg=dtheta_deg, theta_rot_deg=240, node_prefix='A^+'),
    'node3': create_circle_node_dict(xycenter=XY[1], R=R, dtheta_deg=dtheta_deg, theta_rot_deg=120, node_prefix='A^-')
}

# want to set a particular node label pointed towards the middle of the triangle
# we do this by computing the location of the zero node in each circle and adjusting the rotation according to the desired center node
node1_center_label = 'A_0'
node2_center_label = 'A^+_0'
node3_center_label = 'A^-_0'

# compute the angles from the center of the triangle to each circle center
# triangle_center = (
#     sum(x for x, y in XY) / 3,
#     sum(y for x, y in XY) / 3
# )
# compute the center of the triangle with trig
triangle_center = (
    (XY[0][0] + XY[1][0] + XY[2][0]) / 3,
    (XY[0][1] + XY[1][1] + XY[2][1]) / 3
)  
angles_to_triangle_center = []

for x, y in XY:
    dx = triangle_center[0] - x
    dy = triangle_center[1] - y
    angle = math.degrees(math.atan2(dy, dx))
    angles_to_triangle_center.append(angle)

for _style, _items in NODES.items():
    for _label, _xy, _node_id in _items:
        # get the part of the label after the underscore
        label_suffix = _label.split('_')[-1]
        if label_suffix == '0':
            # set the node ring color to black
            extrastyle = {'nodeoutlinecolor': 'black','nodelw': 1.}
        elif int(label_suffix)<0:
            extrastyle = {'nodealpha': 0.3}
        else:
            extrastyle = {}

        # get the 

        graph.addnode(label=_label, xy=_xy, node_id=_node_id,
                      **NODE_STYLES[_style], **extrastyle)

# # Edges by style. Edit one entry here and every edge drawn in it follows.
# EDGE_STYLES = {
#     # 3  edges: A_2→A_2, A_2→A_1, A_2→A_0
#     'double1': dict(labeloffset=1.8, labelfontsize=24, style='double',
#                     whichedges='both', theta=20,
#                     loopkwargs={'lw': 2, 'arrowlength': 0.4, 'arrowstyle': 'filled', 'arrowscale': 0.900}),
# }

# # (fromnode_id, tonode_id) per style
# EDGES = {
#     'double1': [
#         (5, 10),
#         (5, 9),
#         (5, 8),
#         (5, 7),
#         (6, 5),
#         (15, 5),
#         (14, 5),
#         (13, 5),
#         (12, 5),
#         (11, 5),
#         (4, 10),
#         (4, 9),
#         (4, 8),
#         (4, 7),
#         (4, 6),
#         (4, 15),
#         (4, 14),
#         (4, 13),
#         (4, 12),
#         (4, 11),
#         (3, 10),
#         (3, 9),
#         (3, 8),
#         (3, 7),
#         (3, 6),
#         (3, 15),
#         (3, 14),
#         (3, 13),
#         (3, 12),
#         (3, 11),
#         (2, 10),
#         (2, 9),
#         (2, 8),
#         (2, 7),
#         (2, 6),
#         (2, 15),
#         (2, 14),
#         (2, 13),
#         (2, 12),
#         (1, 10),
#         (1, 9),
#         (1, 8),
#         (1, 7),
#         (1, 6),
#         (1, 15),
#         (1, 14),
#         (1, 13),
#         (1, 12),
#         (1, 11),
#     ],
# }

# for _style, _items in EDGES.items():
#     for _fromnode_id, _tonode_id in _items:
#         graph.addedge(fromnode_id=_fromnode_id, tonode_id=_tonode_id,
#                       **EDGE_STYLES[_style])


# # Ports, transmission lines and their wiring
# # Ports by style. Edit one entry here and every port drawn in it follows.
PORT_STYLES = {
    # 1 port: P1
    'port1': dict(R=0.600, fill='#aab6a8', labelcolor='#ffffff'),
    # 1 port: P1+
    'port2': dict(R=0.600, length=1.100, fill='#929ec0', labelcolor='#ffffff'),
    # 1 port: P1-
    'port3': dict(R=0.600, length=1.100, fill='#cd726c', labelcolor='#ffffff'),
}

# (label, xy, port_id, overrides) per style -- overrides is a dict of per-port keywords
PORTS = {
    'port1': [
        ('P1', (-12.982, 0.000), 1, dict(autoorient=True)),
    ],
    'port2': [
        ('P1+', (0.875, 12.000), 3, dict(angle=0.0)),
    ],
    'port3': [
        ('P1-', (0.714, -11.526), 4, dict(angle=0.0)),
    ],
}

for _style, _items in PORTS.items():
    for _label, _xy, _port_id, _over in _items:
        graph.addport(label=_label, xy=_xy, port_id=_port_id,
                      **PORT_STYLES[_style], **_over)

# # Wires by style. Edit one entry here and every wire drawn in it follows.
# WIRE_STYLES = {
#     # 15 wires
#     'wire': dict(),
# }

# # (start, end) per style
# WIRES = {
#     'wire': [
#         (('port', 1), ('node', 5)),
#         (('port', 1), ('node', 4)),
#         (('port', 1), ('node', 3)),
#         (('port', 1), ('node', 2)),
#         (('port', 1), ('node', 1)),
#         (('port', 3), ('node', 10)),
#         (('port', 3), ('node', 9)),
#         (('port', 3), ('node', 8)),
#         (('port', 3), ('node', 7)),
#         (('port', 3), ('node', 6)),
#         (('port', 4), ('node', 15)),
#         (('port', 4), ('node', 14)),
#         (('port', 4), ('node', 13)),
#         (('port', 4), ('node', 12)),
#         (('port', 4), ('node', 11)),
#     ],
# }

# for _style, _items in WIRES.items():
#     for _start, _end in _items:
#         graph.addwire(start=_start, end=_end, **WIRE_STYLES[_style])

graph.addwire(start=('node', 6), end=('node', 16))

# Draw the graph
# overfrac adds padding around the graph to ensure all elements are visible
# Increase overfrac if labels or self-loops are cut off
graph.draw(figsize=12, overfrac=0.2)

# plt.axis('on')
# plt.grid(True)
# # DEBUG: Mark the triangle center on the plot
# plt.plot(triangle_center[0], triangle_center[1], 'ro')  # Mark the triangle center
# # show the triangle and rescale the plot to fit all elements
# x = [xy[0] for xy in XY]
# y = [xy[1] for xy in XY]
# # need to close the triangle by adding the first point at the end
# x.append(x[0])
# y.append(y[0])
# plt.plot(x, y)
# # fit the triangle within the plot limits
# plt.xlim(min(x) - 1, max(x) + 1)
# plt.ylim(min(y) - 1, max(y) + 1)
# plt.gca().set_aspect('equal', adjustable='box')

plt.title('')  # Remove title
plt.show()

# %%
# Out:
# (0, 0)

# %%
74 * math.sin(math.radians(60))
# Out:
# 64.08587988004845

# %%
NODES
# Out:
# {'node1': [('A_-16', (-16.0, -1.959434878635765e-15), 1),
#   ('A_-15', (-15.454813220625091, -4.141104721640336), 2),
#   ('A_-14', (-13.85640646055102, -7.999999999999999), 3),
#   ('A_-13', (-11.31370849898476, -11.313708498984761), 4),
#   ('A_-12', (-7.999999999999997, -13.85640646055102), 5),
#   ('A_-11', (-4.141104721640334, -15.454813220625093), 6),
#   ('A_-10', (9.797174393178826e-16, -16.0), 7),
#   ('A_-9', (4.141104721640332, -15.454813220625093), 8),
#   ('A_-8', (8.000000000000002, -13.856406460551018), 9),
#   ('A_-7', (11.313708498984761, -11.31370849898476), 10),
#   ('A_-6', (13.85640646055102, -7.999999999999999), 11),
#   ('A_-5', (15.454813220625093, -4.141104721640332), 12),
#   ('A_-4', (16.0, 0.0), 13),
#   ('A_-3', (15.454813220625093, 4.141104721640332), 14),
#   ('A_-2', (13.85640646055102, 7.999999999999999), 15),
#   ('A_-1', (11.313708498984761, 11.31370849898476), 16),
#   ('A_0', (8.000000000000002, 13.856406460551018), 17),
# ...
